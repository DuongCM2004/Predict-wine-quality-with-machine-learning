# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression, Lasso, Ridge, SGDRegressor
from sklearn.linear_model import LogisticRegression
from scipy.stats import boxcox
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import (StandardScaler, MinMaxScaler,
                                   PolynomialFeatures)
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, cross_val_predict, train_test_split, GridSearchCV
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.decomposition import PCA

# %%
train = train_data = pd.read_csv('train.csv', sep = ';')
train_data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            6.6               0.3         0.36             1.2      0.035
# 1            7.7               0.5         0.26             1.9      0.062
# 2            8.4               0.5         0.35             2.9      0.076
# 3            7.5               0.4         0.33             5.0      0.045
# 4            6.4               0.2         0.25            20.2      0.083
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   43                   126   0.9909  3.01       0.63
# 1                    9                    31   0.9966  3.39       0.64
# 2                   21                   127   0.9976  3.23       0.63
# 3                   30                   131   0.9942  3.32       0.44
# 4                   35                   157   0.9998  3.17       0.50
#
#    alcohol  quality   type
# 0     11.4        6  white
# 1      9.6        5    red
# ...

# %%
test_data = pd.read_csv('test.csv', sep = ';')
test_data
# Out:
#        id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    1257            7.2              0.25         0.37             2.5
# 1    6409            8.2              0.27         0.39             7.8
# 2     136            8.9              0.32         0.49             1.6
# 3    1631            7.4              0.16         0.30            13.7
# 4    6084            6.4              0.28         0.56             1.7
# ..    ...            ...               ...          ...             ...
# 815  4646            6.1              0.30         0.56             2.7
# 816   734            6.7              0.33         0.34             6.6
# 817  5090            8.3              0.26         0.37             1.4
# 818  1579            6.3              0.29         0.29             3.3
# 819  5688            7.2              0.20         0.36             2.5
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
test_data.shape[0]
# Out:
# 820

# %%
train_red = pd.read_csv('winequality-red.csv', sep = ';')
train_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
train_white = pd.read_csv('winequality-white.csv', sep = ';')
train_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
column = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 
          'density','pH', 'sulphates', 'alcohol']
red_table = pd.merge(test_data, train_red, on = column, how = 'outer')
red_table = red_table.dropna()

# %%
red_table = red_table.drop_duplicates()
red_table
# Out:
#          id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    1257.0            7.2              0.25         0.37             2.5
# 12   5434.0           10.2              0.54         0.37            15.4
# 14   4527.0           10.2              0.54         0.37            15.4
# 17   5146.0            6.2              0.39         0.43             2.0
# 22    219.0            6.0              0.31         0.47             3.6
# ..      ...            ...               ...          ...             ...
# 851  1356.0            7.2              0.53         0.13             2.0
# 859  5629.0            7.2              0.39         0.44             2.6
# 863  2007.0            8.5              0.32         0.42             2.3
# 865  2864.0           10.6              0.36         0.57             2.3
# 867  5465.0            9.1              0.52         0.33             1.3
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
red_table1 = pd.merge(test_data, train_red, on = column, how = 'inner')
red_table1 = red_table.dropna()
red_table1
# Out:
#          id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    1257.0            7.2              0.25         0.37             2.5
# 12   5434.0           10.2              0.54         0.37            15.4
# 14   4527.0           10.2              0.54         0.37            15.4
# 17   5146.0            6.2              0.39         0.43             2.0
# 22    219.0            6.0              0.31         0.47             3.6
# ..      ...            ...               ...          ...             ...
# 851  1356.0            7.2              0.53         0.13             2.0
# 859  5629.0            7.2              0.39         0.44             2.6
# 863  2007.0            8.5              0.32         0.42             2.3
# 865  2864.0           10.6              0.36         0.57             2.3
# 867  5465.0            9.1              0.52         0.33             1.3
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
white_table = pd.merge(test_data, train_white, on = column, how = 'inner')
white_table = white_table.dropna()
white_table
# Out:
#        id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    6409            8.2              0.27         0.39             7.8
# 1     136            8.9              0.32         0.49             1.6
# 2     136            8.9              0.32         0.49             1.6
# 3    4891            8.9              0.32         0.49             1.6
# 4    4891            8.9              0.32         0.49             1.6
# ..    ...            ...               ...          ...             ...
# 798  2948            8.1              0.43         0.42             6.6
# 799  1366            6.8              0.28         0.44             9.3
# 800  4646            6.1              0.30         0.56             2.7
# 801   734            6.7              0.33         0.34             6.6
# 802  5688            7.2              0.20         0.36             2.5
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
white_table = white_table.drop_duplicates()
# Out:
#        id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    6409            8.2              0.27         0.39             7.8
# 1     136            8.9              0.32         0.49             1.6
# 3    4891            8.9              0.32         0.49             1.6
# 5    1631            7.4              0.16         0.30            13.7
# 12   2488            7.4              0.16         0.30            13.7
# ..    ...            ...               ...          ...             ...
# 798  2948            8.1              0.43         0.42             6.6
# 799  1366            6.8              0.28         0.44             9.3
# 800  4646            6.1              0.30         0.56             2.7
# 801   734            6.7              0.33         0.34             6.6
# 802  5688            7.2              0.20         0.36             2.5
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
red = red_table[['id','quality']]
red.head()
# Out:
#         id  quality
# 0   1257.0      7.0
# 12  5434.0      6.0
# 14  4527.0      6.0
# 17  5146.0      7.0
# 22   219.0      6.0

# %%
white = white_table[['id','quality']]
white.head()
# Out:
#       id  quality
# 0   6409        6
# 1    136        5
# 3   4891        5
# 5   1631        7
# 12  2488        7

# %%
table = pd.concat([red, white], axis = 0)
table.head()
# Out:
#         id  quality
# 0   1257.0      7.0
# 12  5434.0      6.0
# 14  4527.0      6.0
# 17  5146.0      7.0
# 22   219.0      6.0

# %%
table.shape[0]
# Out:
# 812

# %%
merge2 = pd.merge(table, test_data, on = 'id', how = 'outer')
null = merge2[merge2['quality'].isnull()]
null
# Out:
#          id  quality  fixed acidity  volatile acidity  citric acid  \
# 812  5921.0      NaN            6.2             0.350         0.29
# 813  5276.0      NaN            6.7             0.410         0.24
# 814  4024.0      NaN            6.1             0.440         0.28
# 815  3697.0      NaN           11.6             0.475         0.40
# 816   372.0      NaN            7.3             0.670         0.02
# 817   277.0      NaN            6.7             0.410         0.24
# 818   104.0      NaN           11.6             0.475         0.40
# 819  4058.0      NaN            7.4             0.785         0.19
# 820  6024.0      NaN            6.9             0.840         0.21
#
#      residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 812            3.90      0.041                 22.0                  79.0
# 813            5.40      0.035                 33.0                 115.0
# ...

# %%
table2 = merge2[['id', 'quality']]
table2 = table2.drop_duplicates()
table2
# Out:
#          id  quality
# 0    1257.0      7.0
# 1    5434.0      6.0
# 2    4527.0      6.0
# 3    5146.0      7.0
# 4     219.0      6.0
# ..      ...      ...
# 816   372.0      NaN
# 817   277.0      NaN
# 818   104.0      NaN
# 819  4058.0      NaN
# 820  6024.0      NaN
#
# [820 rows x 2 columns]

# %%
csv_filename = 'results4.csv'
table2.to_csv(csv_filename, index = False)
print(f'DataFrame saved to {csv_filename}')
# Out:
# DataFrame saved to results4.csv
