# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression, Lasso, Ridge, SGDRegressor
from scipy.stats import boxcox
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import (StandardScaler, MinMaxScaler,
                                   PolynomialFeatures)
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, cross_val_predict, train_test_split, GridSearchCV
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv', sep =';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               6.6               0.3         0.36             1.2      0.035
# 1               7.7               0.5         0.26             1.9      0.062
# 2               8.4               0.5         0.35             2.9      0.076
# 3               7.5               0.4         0.33             5.0      0.045
# 4               6.4               0.2         0.25            20.2      0.083
# ...             ...               ...          ...             ...        ...
# 6709            7.2               0.2         0.19             7.7      0.045
# 6710            6.7               0.3         0.34             7.5      0.036
# 6711            6.6               0.3         0.24             3.3      0.034
# 6712            8.0               0.2         0.31             5.6      0.049
# 6713            6.4               0.3         0.20            15.6      0.040
#
# ...

# %%
df1 = df.drop_duplicates()
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               6.6               0.3         0.36             1.2      0.035
# 1               7.7               0.5         0.26             1.9      0.062
# 2               8.4               0.5         0.35             2.9      0.076
# 3               7.5               0.4         0.33             5.0      0.045
# 4               6.4               0.2         0.25            20.2      0.083
# ...             ...               ...          ...             ...        ...
# 6708            7.1               0.5         0.03             2.6      0.076
# 6709            7.2               0.2         0.19             7.7      0.045
# 6710            6.7               0.3         0.34             7.5      0.036
# 6712            8.0               0.2         0.31             5.6      0.049
# 6713            6.4               0.3         0.20            15.6      0.040
#
# ...

# %%
test = pd.read_csv('test.csv', sep =';')
test.head()
# Out:
#      id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  1257            7.2              0.25         0.37             2.5
# 1  6409            8.2              0.27         0.39             7.8
# 2   136            8.9              0.32         0.49             1.6
# 3  1631            7.4              0.16         0.30            13.7
# 4  6084            6.4              0.28         0.56             1.7
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.063                 11.0                  41.0  0.99439  3.52
# 1      0.039                 49.0                 208.0  0.99760  3.31
# 2      0.050                 17.0                 131.0  0.99560  3.13
# 3      0.056                 33.0                 168.0  0.99825  2.90
# 4      0.156                 49.0                 106.0  0.99354  3.10
#
#    sulphates  alcohol   type
# 0       0.80     12.4    red
# 1       0.51      9.5  white
# ...

# %%
id = test['id']
test = test.drop(columns = ['id'])
test
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.2              0.25         0.37             2.5      0.063
# 1              8.2              0.27         0.39             7.8      0.039
# 2              8.9              0.32         0.49             1.6      0.050
# 3              7.4              0.16         0.30            13.7      0.056
# 4              6.4              0.28         0.56             1.7      0.156
# ..             ...               ...          ...             ...        ...
# 815            6.1              0.30         0.56             2.7      0.046
# 816            6.7              0.33         0.34             6.6      0.067
# 817            8.3              0.26         0.37             1.4      0.076
# 818            6.3              0.29         0.29             3.3      0.037
# 819            7.2              0.20         0.36             2.5      0.028
#
# ...

# %%
X_test = test.drop(columns = 'type')

# %%
one_hot_encoded_data = pd.get_dummies(df1, columns = ['type'])
one_hot_encoded_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               6.6               0.3         0.36             1.2      0.035
# 1               7.7               0.5         0.26             1.9      0.062
# 2               8.4               0.5         0.35             2.9      0.076
# 3               7.5               0.4         0.33             5.0      0.045
# 4               6.4               0.2         0.25            20.2      0.083
# ...             ...               ...          ...             ...        ...
# 6708            7.1               0.5         0.03             2.6      0.076
# 6709            7.2               0.2         0.19             7.7      0.045
# 6710            6.7               0.3         0.34             7.5      0.036
# 6712            8.0               0.2         0.31             5.6      0.049
# 6713            6.4               0.3         0.20            15.6      0.040
#
# ...

# %%
y = one_hot_encoded_data['quality']
X = one_hot_encoded_data.drop(columns = ['quality','type_red','type_white'])

# %%
for column in X.columns:
    X[column] = boxcox(X[column])[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 for column in X.columns:
# ----> 2     X[column] = boxcox(X[column])[0]
#
# File C:\Users\IT tools\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1102, in boxcox(x, lmbda, alpha, optimizer)
#    1099     raise ValueError("Data must not be constant.")
#    1101 if np.any(x <= 0):
# -> 1102     raise ValueError("Data must be positive.")
#    1104 # If lmbda=None, find the lmbda that maximizes the log-likelihood function.
#    1105 lmax = boxcox_normmax(x, method='mle', optimizer=optimizer)
#
# ValueError: Data must be positive.

# %%
poly = PolynomialFeatures(degree = 2, include_bias = False)
ss = StandardScaler()
X_train_s = ss.fit_transform(X)
X_test_s = ss.transform(X_test)
X_train_poly = poly.fit_transform(X_train_s)
X_test_poly = poly.transform(X_test_s)

# %%
lr = LinearRegression()
lr.fit(X_train_poly, y)

# %%
predicted2 = lr.predict(X_test_poly)

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),       # Step 1: Feature scaling
    ('poly_features', PolynomialFeatures()),
    ('linear', LinearRegression())]) # Step 2: Logistic Regression model

# %%
#pipeline.fit(X, y)

# %%
#predicted = pipeline.predict(X_test)

# %%
data = {'id': id, 'quality': predicted2}

# %%
dataframe = pd.DataFrame(data)
csv_filename = 'results.csv'
dataframe.to_csv(csv_filename, index = False)
print(f'DataFrame saved to {csv_filename}')
